# %%
import dhlab as dh
import pandas as pd

# %%
tot = dh.totals(200000)

# %%
paradigms = dh.WordParadigm([x for x in tot.index]).frame

# %%
forms = dh.WordForm([x for x in tot.index]).frame

# %%
paradigms.columns=  ["word","pos", "paradigm"]

# %%
forms.columns = ["word", "form"]

# %%
paradigms[paradigms.word.isin(paradigms[paradigms.word=="fisker"].iloc[0].paradigm)]
# Out:
#          word   pos                                      paradigm
# 17201   fiska   adj   [fiska, fiskede, fiskende, fisket, fiskete]
# 17202   fiska  subs       [fiska, fiske, fiskene, fisker, fisket]
# 17203   fiska  verb  [fisk, fiska, fiske, fisker, fiskes, fisket]
# 17278  fisket   adj   [fiska, fiskede, fiskende, fisket, fiskete]
# 17279  fisket  subs       [fiska, fiske, fiskene, fisker, fisket]
# 17280  fisket  verb  [fisk, fiska, fiske, fisker, fiskes, fisket]

# %%
[x for x in paradigms[paradigms.word=="fisker"].iloc[2].paradigm if x in paradigms.index]
# Out:
# []

# %%
paradigms[paradigms.word=="fisker"].iloc[2]
# Out:
# word                                              fisker
# pos                                                 verb
# paradigm    [fisk, fiska, fiske, fisker, fiskes, fisket]
# Name: 17244, dtype: object

# %%
def analyze_paradigm_ambiguity(paradigms_df):
    # Group by word to find words with multiple paradigms
    ambiguous = paradigms_df.groupby('word').agg({
        'pos': lambda x: list(x),
        'paradigm': lambda x: list(x)
    }).reset_index()
    
    # Filter for words that appear in multiple paradigms
    ambiguous = ambiguous[ambiguous['pos'].str.len() > 1]
    return ambiguous

# Then for analyzing form distributions:
def analyze_form_distributions(paradigms_df):
    # Create distributions of forms within each POS
    pos_form_distributions = {}
    for pos in paradigms_df['pos'].unique():
        pos_paradigms = paradigms_df[paradigms_df['pos'] == pos]
        # Flatten all paradigms for this POS
        all_forms = [form for paradigm in pos_paradigms['paradigm'] for form in paradigm]
        # Calculate frequency distribution
        forms_freq = pd.Series(all_forms).value_counts(normalize=True)
        pos_form_distributions[pos] = forms_freq
    return pos_form_distributions

# %%
def estimate_paradigm_probability(word_form, form_distributions):
    probs = {}
    for pos, distribution in form_distributions.items():
        if word_form in distribution:
            probs[pos] = distribution[word_form]
    # Normalize probabilities
    total = sum(probs.values())
    return {pos: prob/total for pos, prob in probs.items()}

# %%
ambig = analyze_paradigm_ambiguity(paradigms)

# %%
ambig
# Out:
#         word                 pos  \
# 0          A         [adv, subs]
# 5        A/S        [fork, henv]
# 49        CD        [fork, subs]
# 86         E        [fork, subs]
# 142        I  [pron, subs, symb]
# ...      ...                 ...
# 60152   øyer   [adj, subs, verb]
# 60159   øyne   [adj, subs, verb]
# 60161  øyner         [adj, verb]
# 60162  øynes         [adj, verb]
# 60163  øynet         [adj, verb]
#
#                                                 paradigm
# 0                    [[A], [A, A'en, A-en, A-ene, A-er]]
# 5                 [[A.S, A/S, AS, a.s., a/s, as], [A/S]]
# 49                       [[CD], [CD, CDen, CDene, CDer]]
# 86                   [[E], [E, E'en, E-en, E-ene, E-er]]
# 142    [[Eder, I, eder], [I, I'en, I-en, I-ene, I-er]...
# ...                                                  ...
# 60152  [[øyd, øyde, øyende], [øy, øya, øyen, øyene, ø...
# 60159  [[øyna, øynede, øynende, øynet, øynete], [øya,...
# 60161  [[øyna, øynede, øynende, øynet, øynete], [øyn,...
# 60162  [[øyna, øynede, øynende, øynet, øynete], [øyn,...
# 60163  [[øyna, øynede, øynende, øynet, øynete], [øyn,...
#
# [18155 rows x 3 columns]

# %%
# First, get clean forms for all words in paradigms
paradigm_words = set([word for paradigm_list in paradigms['paradigm'] for word in paradigm_list])
word_forms = dh.WordForm(list(paradigm_words)).frame

# %%
def clean_word_forms(word_forms_df):
    def extract_basic_form(form_str):
        parts = form_str.split()
        base_pos = parts[0]  # First part is usually the POS
        
        # Handle adverbs - any form string starting with 'adv' should be marked as adverb
        if base_pos == 'adv':
            return 'adverb'
            
        elif base_pos == 'verb':
            if 'inf' in parts:
                return 'infinitive'
            elif 'perf-part' in parts:
                return 'perfect-participle'
            elif 'pres-part' in parts:
                return 'present-participle'
            elif 'pret' in parts:
                return 'preterite'
            elif 'pres' in parts:
                return 'present'
            elif 'imp' in parts:
                return 'imperative'
            return 'unknown-verb'
                
        elif base_pos == 'subst':
            form = []
            if 'ent' in parts:
                form.append('singular')
            elif 'fl' in parts:
                form.append('plural')
            if 'be' in parts:
                form.append('definite')
            elif 'ub' in parts:
                form.append('indefinite')
            return '-'.join(form) if form else 'unknown-noun'
            
        elif base_pos == 'adj':
            if '<perf-part>' in form_str:
                return 'participle-adj'
            elif 'pos' in parts:
                return 'positive'
            elif 'komp' in parts:
                return 'comparative'
            elif 'sup' in parts:
                return 'superlative'
            return 'unknown-adj'
            
        return f'unknown-{base_pos}'

    word_forms_df['clean_form'] = word_forms_df['form'].apply(extract_basic_form)
    return word_forms_df

# %%
# Then analyze distributions
def analyze_paradigm_distributions(paradigms_df, word_forms_df):
    # Group word forms by their base form to get form types
    form_types = {}
    for _, row in word_forms_df.iterrows():
        form_types[row['word']] = row['clean_form']  # Assuming 'form' is the column with form type
    
    # Analyze distribution within each POS type
    pos_distributions = {}
    for pos in paradigms_df['pos'].unique():
        pos_forms = []
        # Get all forms from paradigms of this POS
        pos_paradigms = paradigms_df[paradigms_df['pos'] == pos]
        for paradigm in pos_paradigms['paradigm']:
            forms = [form_types.get(word, 'unknown') for word in paradigm]
            pos_forms.extend(forms)
        
        # Calculate distribution
        distribution = pd.Series(pos_forms).value_counts(normalize=True)
        pos_distributions[pos] = distribution
    
    return pos_distributions

# %%
word_forms.columns = ["word","form"]

# %%
word_forms[word_forms.form.str.startswith("subst")]
# Out:
#                   word                              form         clean_form
# 0               lønnen  subst mask appell ent be normert  singular-definite
# 4           karrierene   subst fem appell fl be unormert    plural-definite
# 5           karrierene   subst mask appell fl be normert    plural-definite
# 7           verdensrya   subst nøyt appell fl be normert    plural-definite
# 8          overdekkene   subst nøyt appell fl be normert    plural-definite
# ...                ...                               ...                ...
# 247057      farmødrene    subst fem appell fl be normert    plural-definite
# 247058      farmødrene   subst mask appell fl be normert    plural-definite
# 247059  bybefolkninger    subst fem appell fl ub normert  plural-indefinite
# 247060  bybefolkninger   subst mask appell fl ub normert  plural-indefinite
# 247081         ugagnet  subst nøyt appell ent be normert  singular-definite
#
# [120915 rows x 3 columns]

# %%
tot
# Out:
#                    freq
# .            7655423257
# ,            5052171514
# i            2531262027
# og           2520268056
# -            1314451583
# ...                 ...
# enterprises       17126
# Isaiah            17126
# velprøvd          17125
# udløb             17125
# budstikka         17125
#
# [200000 rows x 1 columns]

# %%
# Example usage:
cleaned_forms = clean_word_forms(word_forms)

# %%
pos = analyze_paradigm_distributions(paradigms, cleaned_forms)

# %%
pos
# Out:
# {'adv': adverb                 0.750594
#  imperative             0.097387
#  singular-indefinite    0.057007
#  plural-indefinite      0.042755
#  preterite              0.009501
#  perfect-participle     0.007126
#  unknown-sbu            0.004751
#  positive               0.004751
#  unknown-noun           0.004751
#  singular-definite      0.004751
#  unknown-interj         0.004751
#  unknown-symb           0.002375
#  unknown-prep           0.002375
#  unknown-det            0.002375
#  infinitive             0.002375
#  unknown-konj           0.002375
#  Name: proportion, dtype: float64,
#  'subs': plural-definite        0.271342
#  singular-definite      0.268347
#  plural-indefinite      0.228297
#  singular-indefinite    0.161466
#  imperative             0.027228
#  preterite              0.020067
#  present                0.012794
#  positive               0.004110
#  infinitive             0.002312
#  unknown-noun           0.002245
#  perfect-participle     0.000638
#  participle-adj         0.000252
#  adverb                 0.000218
#  unknown-interj         0.000140
#  unknown-henv           0.000090
#  unknown-fork           0.000090
#  unknown-symb           0.000067
#  unknown-pron           0.000067
#  comparative            0.000056
#  unknown-det            0.000056
#  unknown-prep           0.000039
#  unknown-sbu            0.000028
#  superlative            0.000022
#  unknown-verb           0.000017
#  plural                 0.000006
#  unknown-adj            0.000006
#  Name: proportion, dtype: float64,
#  'fork': unknown-fork           0.907514
#  unknown-henv           0.057803
#  imperative             0.020231
#  unknown-symb           0.005780
#  unknown-prep           0.004335
#  singular-indefinite    0.002890
#  positive               0.001445
#  Name: proportion, dtype: float64,
#  'henv': unknown-henv           0.837838
#  singular-indefinite    0.054054
#  unknown-fork           0.027027
#  unknown-symb           0.027027
#  unknown-pron           0.027027
#  imperative             0.027027
#  Name: proportion, dtype: float64,
#  'symb': unknown-symb           0.981366
#  singular-indefinite    0.012422
#  imperative             0.006211
#  Name: proportion, dtype: float64,
#  'pron': unknown-pron           0.609375
#  imperative             0.093750
#  unknown-det            0.078125
#  preterite              0.062500
#  plural-indefinite      0.046875
#  unknown-symb           0.046875
#  singular-indefinite    0.031250
#  unknown-sbu            0.015625
#  unknown-noun           0.015625
#  Name: proportion, dtype: float64,
#  'det': unknown-det            0.682482
#  imperative             0.083942
#  unknown-pron           0.080292
#  infinitive             0.029197
#  plural-indefinite      0.018248
#  unknown-symb           0.018248
#  singular-indefinite    0.018248
#  unknown-interj         0.018248
#  perfect-participle     0.014599
#  unknown-konj           0.014599
#  unknown-fork           0.014599
#  adverb                 0.007299
#  Name: proportion, dtype: float64,
#  'adj': preterite              0.191652
#  positive               0.176623
#  participle-adj         0.167573
#  superlative            0.137754
#  unknown-adj            0.131131
#  perfect-participle     0.074829
#  comparative            0.067090
#  singular-definite      0.013905
#  singular-indefinite    0.009865
#  imperative             0.009190
#  infinitive             0.008236
#  plural-definite        0.003211
#  plural-indefinite      0.003172
#  unknown-noun           0.002567
#  adverb                 0.002505
#  unknown-prep           0.000225
#  unknown-det            0.000140
#  unknown-interj         0.000116
#  unknown-henv           0.000109
#  unknown-sbu            0.000085
#  unknown-adjektiv       0.000023
#  Name: proportion, dtype: float64,
#  'inte': unknown-interj         0.365217
#  imperative             0.321739
#  plural-indefinite      0.147826
#  singular-indefinite    0.069565
#  preterite              0.034783
#  unknown-symb           0.017391
#  unknown-noun           0.017391
#  plural-definite        0.008696
#  unknown-pron           0.008696
#  unknown-fork           0.008696
#  Name: proportion, dtype: float64,
#  'prep': unknown-prep           0.828947
#  unknown-noun           0.046053
#  imperative             0.046053
#  singular-indefinite    0.032895
#  plural-indefinite      0.019737
#  preterite              0.009868
#  unknown-symb           0.003289
#  unknown-det            0.003289
#  unknown-henv           0.003289
#  unknown-pron           0.003289
#  unknown-interj         0.003289
#  Name: proportion, dtype: float64,
#  'verb': infinitive             0.285834
#  preterite              0.251336
#  imperative             0.143458
#  present                0.111168
#  perfect-participle     0.084430
#  singular-indefinite    0.057535
#  plural-indefinite      0.025708
#  positive               0.015975
#  singular-definite      0.014918
#  plural-definite        0.003658
#  unknown-noun           0.002235
#  adverb                 0.000995
#  participle-adj         0.000629
#  unknown-det            0.000454
#  unknown-interj         0.000454
#  unknown-prep           0.000367
#  comparative            0.000175
#  unknown-henv           0.000122
#  unknown-verb           0.000113
#  unknown-konj           0.000105
#  unknown-symb           0.000105
#  unknown-pron           0.000079
#  unknown-fork           0.000079
#  unknown-sbu            0.000052
#  superlative            0.000017
#  Name: proportion, dtype: float64,
#  'pref': unknown-pref    1.0
#  Name: proportion, dtype: float64,
#  'sbu': unknown-sbu            0.866667
#  unknown-prep           0.033333
#  plural-indefinite      0.033333
#  present                0.033333
#  singular-indefinite    0.033333
#  Name: proportion, dtype: float64,
#  'konj': unknown-konj         0.777778
#  imperative           0.111111
#  plural-indefinite    0.111111
#  Name: proportion, dtype: float64,
#  'adje': unknown-adjektiv    1.0
#  Name: proportion, dtype: float64,
#  'CLB': unknown-konj    0.5
#  imperative      0.5
#  Name: proportion, dtype: float64,
#  'inf-': imperative    1.0
#  Name: proportion, dtype: float64}

# %%
word_forms[word_forms['form'].str.contains('adj')].iloc[4]
# Out:
# word                                             tvinnede
# form    adj <perf-part> fl <trans1> <refl5> <trans9> n...
# Name: 10, dtype: object

# %%
verb_dist = pos['verb']
print("Verb form distributions:")
print(f"Past tense: {verb_dist.get('past', 0)*100:.1f}%")
print(f"Present: {verb_dist.get('present', 0)*100:.1f}%")
print(f"Infinitive: {verb_dist.get('infinitive', 0)*100:.1f}%")
print(f"Participle: {verb_dist.get('participle', 0)*100:.1f}%")
# Out:
# Verb form distributions:
# Past tense: 0.0%
# Present: 0.0%
# Infinitive: 0.0%
# Participle: 0.0%

# %%
from collections import defaultdict

# %%
from collections import defaultdict
import pandas as pd

def analyze_form_frequencies(paradigms_df, word_forms_df, tot_df):
    # Create lookup for clean forms
    form_lookup = dict(zip(word_forms_df['word'], word_forms_df['clean_form']))
    
    # Dictionary to store frequencies by POS and form
    pos_frequencies = {}
    
    for pos in paradigms_df['pos'].unique():
        form_freqs = defaultdict(int)
        pos_paradigms = paradigms_df[paradigms_df['pos'] == pos]
        
        for _, row in pos_paradigms.iterrows():
            # For each word in the paradigm
            for word in row['paradigm']:
                if word in tot_df.index:
                    # Get the actual frequency value
                    freq = tot_df.loc[word].iloc[0]  # or .values[0] would also work
                    form = form_lookup.get(word, 'unknown')
                    form_freqs[form] += freq
        
        # Convert to proportions
        total = sum(form_freqs.values())
        if total > 0:
            proportions = {form: freq/total for form, freq in form_freqs.items()}
            pos_frequencies[pos] = pd.Series(proportions)
    
    return pos_frequencies

# %%
# Usage:
freq_distributions = analyze_form_frequencies(paradigms, word_forms, tot)

# %%
pos_metadata = {
    'total_occurrences': sum of all frequencies,
    'unique_forms': number of distinct forms,
    'top_forms': most frequent forms,
    'ambiguity_score': measure of form distribution entropy
}

# %%
def compare_form_distributions(raw_dist, freq_dist):
    """Compare raw form distributions with frequency-weighted ones"""
    all_forms = set(raw_dist.index) | set(freq_dist.index)
    
    comparison = pd.DataFrame({
        'raw': [raw_dist.get(form, 0) for form in all_forms],
        'frequency_weighted': [freq_dist.get(form, 0) for form in all_forms]
    }, index=all_forms)
    
    comparison['difference'] = comparison['frequency_weighted'] - comparison['raw']
    return comparison.sort_values('difference', ascending=False)

# %%
freq_distributions
# Out:
# {'adv': adverb                 0.264277
#  unknown-symb           0.028148
#  plural-indefinite      0.108983
#  imperative             0.337237
#  unknown-sbu            0.155197
#  singular-indefinite    0.045803
#  unknown-det            0.006257
#  unknown-prep           0.014774
#  infinitive             0.000338
#  preterite              0.002121
#  unknown-interj         0.015119
#  positive               0.000257
#  perfect-participle     0.010236
#  unknown-konj           0.004186
#  singular-definite      0.000010
#  unknown-noun           0.007058
#  dtype: float64,
#  'subs': adverb                 0.004101
#  singular-indefinite    0.325045
#  plural-indefinite      0.204370
#  singular-definite      0.106573
#  unknown-noun           0.012608
#  unknown-fork           0.006269
#  plural-definite        0.029714
#  unknown-symb           0.017080
#  imperative             0.171191
#  preterite              0.056831
#  present                0.028890
#  unknown-prep           0.000113
#  infinitive             0.013975
#  perfect-participle     0.005412
#  positive               0.004569
#  superlative            0.000461
#  unknown-interj         0.002768
#  participle-adj         0.000211
#  unknown-pron           0.003641
#  unknown-verb           0.000026
#  unknown-adj            0.000001
#  unknown-henv           0.001505
#  unknown-det            0.001573
#  unknown-sbu            0.003025
#  comparative            0.000048
#  dtype: float64,
#  'fork': unknown-fork           0.477098
#  imperative             0.014503
#  unknown-prep           0.002009
#  unknown-henv           0.462037
#  unknown-symb           0.032509
#  positive               0.000235
#  singular-indefinite    0.011609
#  dtype: float64,
#  'henv': unknown-fork           0.019415
#  unknown-henv           0.939275
#  singular-indefinite    0.001312
#  unknown-symb           0.033452
#  unknown-pron           0.006050
#  imperative             0.000495
#  dtype: float64,
#  'symb': unknown-symb           0.981922
#  singular-indefinite    0.017308
#  imperative             0.000770
#  dtype: float64,
#  'pron': unknown-pron           0.224671
#  unknown-symb           0.144229
#  plural-indefinite      0.047169
#  preterite              0.046281
#  unknown-det            0.312431
#  imperative             0.194007
#  singular-indefinite    0.027090
#  unknown-sbu            0.003512
#  unknown-noun           0.000609
#  dtype: float64,
#  'det': unknown-symb           0.013241
#  unknown-det            0.398075
#  plural-indefinite      0.014787
#  unknown-pron           0.033434
#  imperative             0.332626
#  unknown-konj           0.127741
#  perfect-participle     0.006119
#  unknown-interj         0.000517
#  singular-indefinite    0.004979
#  adverb                 0.002623
#  unknown-fork           0.036999
#  infinitive             0.028858
#  dtype: float64,
#  'adj': positive               0.290006
#  preterite              0.195790
#  perfect-participle     0.168930
#  plural-indefinite      0.020404
#  unknown-adj            0.017728
#  imperative             0.070625
#  infinitive             0.033475
#  singular-indefinite    0.057662
#  unknown-noun           0.021149
#  superlative            0.019511
#  comparative            0.040711
#  singular-definite      0.024350
#  unknown-det            0.005883
#  participle-adj         0.008828
#  unknown-prep           0.003369
#  adverb                 0.014767
#  plural-definite        0.000789
#  unknown-adjektiv       0.000003
#  unknown-interj         0.003615
#  unknown-henv           0.001719
#  unknown-sbu            0.000687
#  dtype: float64,
#  'inte': unknown-symb           0.202001
#  plural-indefinite      0.018905
#  unknown-interj         0.103110
#  imperative             0.613428
#  preterite              0.001446
#  singular-indefinite    0.033236
#  plural-definite        0.000037
#  unknown-noun           0.017925
#  unknown-pron           0.009513
#  unknown-fork           0.000398
#  dtype: float64,
#  'prep': unknown-symb           0.014326
#  unknown-prep           0.375994
#  unknown-noun           0.001435
#  unknown-henv           0.084523
#  imperative             0.106119
#  unknown-det            0.047032
#  singular-indefinite    0.273094
#  preterite              0.000473
#  unknown-pron           0.003068
#  plural-indefinite      0.093866
#  unknown-interj         0.000071
#  dtype: float64,
#  'verb': infinitive             9.198011e-02
#  preterite              1.700321e-01
#  imperative             3.317860e-01
#  present                1.390255e-01
#  perfect-participle     5.135652e-02
#  positive               1.691994e-02
#  singular-indefinite    8.660782e-02
#  unknown-prep           6.808685e-04
#  plural-indefinite      3.281045e-02
#  singular-definite      7.343188e-03
#  unknown-noun           1.530354e-02
#  adverb                 7.481260e-03
#  unknown-verb           2.175275e-04
#  unknown-interj         4.643208e-03
#  comparative            1.219587e-03
#  plural-definite        2.401569e-04
#  participle-adj         2.253018e-04
#  unknown-pron           5.487252e-03
#  unknown-det            6.573036e-03
#  unknown-konj           2.192802e-02
#  unknown-henv           8.128702e-05
#  unknown-symb           5.057560e-03
#  unknown-fork           2.927960e-03
#  unknown-sbu            7.162932e-05
#  superlative            1.193717e-07
#  dtype: float64,
#  'pref': unknown-pref    1.0
#  dtype: float64,
#  'sbu': unknown-sbu            0.781231
#  unknown-prep           0.032548
#  plural-indefinite      0.013717
#  present                0.000485
#  singular-indefinite    0.172019
#  dtype: float64,
#  'konj': unknown-konj         0.932083
#  imperative           0.067107
#  plural-indefinite    0.000811
#  dtype: float64,
#  'adje': unknown-adjektiv    1.0
#  dtype: float64,
#  'CLB': unknown-konj    0.686887
#  imperative      0.313113
#  dtype: float64,
#  'inf-': imperative    1.0
#  dtype: float64}

# %%
tot.loc[[x.strip() for x in "bok, boka, boken, bøker, bøkene".split(',')]].to_csv()
# Out:
# ',freq\nbok,8044500\nboka,3299703\nboken,3623884\nbøker,4804941\nbøkene,1412713\n'

# %%
tot.loc[[x.strip() for x in "kvinne, kvinnen, kvinner, kvinnene".split(',')]]
# Out:
#               freq
# kvinne     6769333
# kvinnen    3103342
# kvinner   14345018
# kvinnene   2676898
